# %%
import os
os.chdir('/home/victor/_bcfl/fabric-federated-learning/federated-learning')  # Replace with the path to your project
import sys
sys.path.append('/home/victor/_bcfl/fabric-federated-learning/federated-learning')  # Replace with the path to your models directory
print(sys.path)

# %load_ext autoreload
# %autoreload 2
# Out:
# ['/home/victor/_bcfl/fabric-federated-learning/federated-learning/client/notebooks', '/home/victor/anaconda3/envs/bcfl-fabric/lib/python311.zip', '/home/victor/anaconda3/envs/bcfl-fabric/lib/python3.11', '/home/victor/anaconda3/envs/bcfl-fabric/lib/python3.11/lib-dynload', '', '/home/victor/anaconda3/envs/bcfl-fabric/lib/python3.11/site-packages', '/home/victor/_bcfl/fabric-federated-learning/federated-learning', '/tmp/tmpwr01kccf', '/home/victor/_bcfl/fabric-federated-learning/federated-learning']
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Running in colaboratory
# !git clone https://github.com/vdevictor96/fabric-federated-learning
# %cd fabric-federated-learning/federated-learning/
# !git pull

# %%
# !python -m client.run_test --config_file ./client/config/default_test_config.json

# %%
from client.run_test import main
import sys


# Backup the original sys.argv
original_argv = sys.argv

try:
    # Replace sys.argv with the arguments you want to pass
    sys.argv = ['run_test', '--config_file', 'client/config/test/bert_tiny_debug_test_config.json']
    # sys.argv = ['run_test']

    
    # Now call main, and it will use the arguments you set
    main()
finally:
    # Restore the original sys.argv
    sys.argv = original_argv
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at prajjwal1/bert-tiny and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# -------- Loading configuration --------
# Current configuration:
# {
#     "dataset": "twitter_dep",
#     "device": "cuda",
#     "max_length": 512,
#     "model": "bert_tiny",
#     "model_path": "client/models/bert_tiny/bert_tiny_debug_last.ckpt",
#     "progress_bar_flag": true,
#     "seed": 200,
#     "test_batch_size": 8
# }
# -------- Configuration loaded --------
#
# -------- Setting device --------
# CUDA device selected and available.
# -------- Device set --------
#
# -------- Setting seed --------
# -------- Seed set --------
#
# -------- Loading model from model_path --------
# Loaded model bert-tiny from date 30-01-2024 11:04. Trained with Federated Learning technology.
# Round 1, lr: 6e-05, optimizer: AdamW
# Train accuracy: 60.00 %, Validation accuracy: 0.00 %
# -------- Model loaded --------
#
# -------- Creating Tokenizer --------
# -------- Tokenizer created --------
#
# -------- Creating Test Dataloader --------
# Test Loader: 618 total sentences. 78 batches of size 8.
# -------- Test Dataloader created --------
#
# -------- Testing --------
#   0%|          | 0/78 [00:00<?, ?it/s]
# Nº of samples: 618
# Accuracy: 62.62 %
# Precision: 51.84 %
# Recall: 51.77 %
# F1 Score: 51.78 %
# -------- Testing finished --------
